# %% [markdown]
# # RecoMart Recommendation System: Exploratory Data Analysis & Preparation
#
# This notebook performs data cleaning, categorical encoding, numerical feature scaling, interaction matrix sparsity analysis, and visualization for the RecoMart e-commerce recommendation pipeline.

# %%
import os
import pandas as pd
from src.preparation.data_preparation import run_preparation

eda_stats = run_preparation()
print("EDA Sparsity & Interaction Statistics:", eda_stats)
